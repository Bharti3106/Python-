# %% [markdown]
# #ALL PANDAS OPERATIONS

# %% [markdown]
# # **Importing the Pandas**.
# ###Pandas: Use for analysing the data

# %%
import pandas as pd

# %%
url ="https://raw.githubusercontent.com/Bharti3106/Projects/main/ca3_dataset.csv"
df=pd.read_csv(url)

# %% [markdown]
# ## **Viewing data**

# %% [markdown]
# # **Show Top 5 Row of data set**

# %%
df.head()
# Out:
#   School     Sex  Age Address         Family_size Parent_cohabitation_status  \
# 0     GP  Female   18   Urban      Greater than 3                      Apart
# 1     GP  Female   17   Urban      Greater than 3            Living together
# 2     GP  Female   15   Urban  Less or equal to 3            Living together
# 3     GP  Female   15   Urban      Greater than 3            Living together
# 4     GP  Female   16   Urban      Greater than 3            Living together
#
#    Mother_education  Father_education Mother_job Father_job  ... Famrel  \
# 0                 4                 4    at_home    teacher  ...      4
# 1                 1                 1    at_home      other  ...      5
# 2                 1                 1    at_home      other  ...      4
# 3                 4                 2     health   services  ...      3
# 4                 3                 3      other      other  ...      4
#
#   Free_time  Go_out  Dalc  Walc Health Absences  G1  G2  G3
# ...

# %% [markdown]
# # **Show  last 5 Row of data set**

# %%
df.tail()
# Out:
#     School   Sex  Age Address         Family_size Parent_cohabitation_status  \
# 390     MS  Male   20   Urban  Less or equal to 3                      Apart
# 391     MS  Male   17   Urban  Less or equal to 3            Living together
# 392     MS  Male   21   Rural      Greater than 3            Living together
# 393     MS  Male   18   Rural  Less or equal to 3            Living together
# 394     MS  Male   19   Urban  Less or equal to 3            Living together
#
#      Mother_education  Father_education Mother_job Father_job  ... Famrel  \
# 390                 2                 2   services   services  ...      5
# 391                 3                 1   services   services  ...      2
# 392                 1                 1      other      other  ...      5
# 393                 3                 2   services      other  ...      4
# 394                 1                 1      other    at_home  ...      3
#
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=395, step=1)

# %%
df.columns
# Out:
# Index(['School', 'Sex', 'Age', 'Address', 'Family_size',
#        'Parent_cohabitation_status', 'Mother_education', 'Father_education',
#        'Mother_job', 'Father_job', 'Reason', 'Guardian', 'Trave_ltime',
#        'Study_time', 'Failures', 'Schoolsup', 'Family_educational', 'Paid',
#        'activities', 'Nursery', 'Higher', 'Internet', 'Romantic', 'Famrel',
#        'Free_time', 'Go_out', 'Dalc', 'Walc', 'Health', 'Absences', 'G1', 'G2',
#        'G3'],
#       dtype='object')

# %% [markdown]
# # **Convert the DataFrame to a NumPy array.**

# %%
df['Age'].to_numpy
# Out:
# <bound method IndexOpsMixin.to_numpy of 0      18
# 1      17
# 2      15
# 3      15
# 4      16
#        ..
# 390    20
# 391    17
# 392    21
# 393    18
# 394    19
# Name: Age, Length: 395, dtype: int64>

# %% [markdown]
# #**Sort_values() sorts by values:**

# %%
df.sort_values(by="G1")
# Out:
#     School     Sex  Age Address         Family_size  \
# 248     GP    Male   18   Rural  Less or equal to 3
# 137     GP  Female   16   Urban      Greater than 3
# 0       GP  Female   18   Urban      Greater than 3
# 1       GP  Female   17   Urban      Greater than 3
# 79      GP  Female   16   Urban      Greater than 3
# ..     ...     ...  ...     ...                 ...
# 129     GP    Male   16   Rural      Greater than 3
# 245     GP    Male   16   Urban      Greater than 3
# 374     MS  Female   18   Rural  Less or equal to 3
# 42      GP    Male   15   Urban      Greater than 3
# 47      GP    Male   16   Urban      Greater than 3
#
#     Parent_cohabitation_status  Mother_education  Father_education Mother_job  \
# 248            Living together                 3                 3      other
# 137                      Apart                 3                 3      other
# 0                        Apart                 4                 4    at_home
# ...

# %% [markdown]
# # **Show rows and column present in data set**.

# %%
df.shape
# Out:
# (395, 33)

# %% [markdown]
#  # **Detect Missing Values**
#  ### NA values, such as None or numpy.NaN, gets mapped to True values. Everything else gets mapped to False values.

# %%
df.isna()
# Out:
#      School    Sex    Age  Address  Family_size  Parent_cohabitation_status  \
# 0     False  False  False    False        False                       False
# 1     False  False  False    False        False                       False
# 2     False  False  False    False        False                       False
# 3     False  False  False    False        False                       False
# 4     False  False  False    False        False                       False
# ..      ...    ...    ...      ...          ...                         ...
# 390   False  False  False    False        False                       False
# 391   False  False  False    False        False                       False
# 392   False  False  False    False        False                       False
# 393   False  False  False    False        False                       False
# 394   False  False  False    False        False                       False
#
# ...

# %% [markdown]
# # **Description of the data in the DataFrame**.
# quick statistic summary of your data:

# %%
df.describe()
# Out:
#               Age  Mother_education  Father_education  Trave_ltime  \
# count  395.000000        395.000000        395.000000   395.000000
# mean    16.696203          2.749367          2.521519     1.448101
# std      1.276043          1.094735          1.088201     0.697505
# min     15.000000          0.000000          0.000000     1.000000
# 25%     16.000000          2.000000          2.000000     1.000000
# 50%     17.000000          3.000000          2.000000     1.000000
# 75%     18.000000          4.000000          3.000000     2.000000
# max     22.000000          4.000000          4.000000     4.000000
#
#        Study_time    Failures      Famrel   Free_time      Go_out        Dalc  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     2.035443    0.334177    3.944304    3.235443    3.108861    1.481013
# std      0.839240    0.743651    0.896659    0.998862    1.113278    0.890741
# ...

# %% [markdown]
# ---

# %% [markdown]
# # **Numerical analysis**
# ### We'll analyze the "G1" ( Grade 1 ) column

# %% [markdown]
# # **Accesing a coloum**.

# %%
x=df['G1']
x
# Out:
# 0       5
# 1       5
# 2       7
# 3      15
# 4       6
#        ..
# 390     9
# 391    14
# 392    10
# 393    11
# 394     8
# Name: G1, Length: 395, dtype: int64

# %%
x.head(10)
# Out:
# 0     5
# 1     5
# 2     7
# 3    15
# 4     6
# 5    15
# 6    12
# 7     6
# 8    16
# 9    14
# Name: G1, dtype: int64

# %%
x.max()
# Out:
# 19

# %%
x.median()
# Out:
# 11.0

# %%
x.mean()
# Out:
# 10.90886075949367

# %%
x.describe()
# Out:
# count    395.000000
# mean      10.908861
# std        3.319195
# min        3.000000
# 25%        8.000000
# 50%       11.000000
# 75%       13.000000
# max       19.000000
# Name: G1, dtype: float64

# %% [markdown]
# # **Each column in a DataFrame is a Series. As a single column is selected, the returned object is a pandas Series. We can verify this by checking the type of the output:**

# %%
type(x)
# Out:
# pandas.core.series.Series

# %%
x.shape
# Out:
# (395,)

# %% [markdown]
# # **I’m interested in the g1 and g2 of the students**.

# %%
G1_G2 = df[['G1','G2']]
G1_G2
# Out:
#      G1  G2
# 0     5   6
# 1     5   5
# 2     7   8
# 3    15  14
# 4     6  10
# ..   ..  ..
# 390   9   9
# 391  14  16
# 392  10   8
# 393  11  12
# 394   8   9
#
# [395 rows x 2 columns]

# %% [markdown]
# # **The returned data type is a pandas DataFrame:**

# %%
type(G1_G2)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # **How do I filter specific rows from a DataFrame?**

# %% [markdown]
# ## Students Detail whose Grade 1 is greater than 15

# %%
above_25 = df[df["G1"]>15]
above_25.head()
# Out:
#    School   Sex  Age Address         Family_size Parent_cohabitation_status  \
# 8      GP  Male   15   Urban  Less or equal to 3                      Apart
# 31     GP  Male   15   Urban      Greater than 3            Living together
# 32     GP  Male   15   Rural      Greater than 3            Living together
# 42     GP  Male   15   Urban      Greater than 3            Living together
# 47     GP  Male   16   Urban      Greater than 3            Living together
#
#     Mother_education  Father_education Mother_job Father_job  ... Famrel  \
# 8                  3                 2   services      other  ...      4
# 31                 4                 4   services   services  ...      4
# 32                 4                 3    teacher    at_home  ...      4
# 42                 4                 4   services    teacher  ...      4
# 47                 4                 3     health   services  ...      4
#
#    Free_time  Go_out  Dalc  Walc Health Absences  G1  G2  G3
# ...

# %%
above_25.shape
# Out:
# (41, 33)

# %% [markdown]
# # notna function

# %% [markdown]
# The notna() conditional function returns a True for each row the values are not a Null value. As such, this can be combined with the selection brackets [] to filter the data table.\

# %%
df['Free_time'].notna()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 390    True
# 391    True
# 392    True
# 393    True
# 394    True
# Name: Free_time, Length: 395, dtype: bool

# %%
no_na=df[df['Free_time'].notna()]
no_na.shape
# Out:
# (395, 33)

# %% [markdown]
# ---

# %% [markdown]
# # **Selection**
# While standard Python / NumPy expressions for selecting and setting are intuitive and come in handy for interactive work, for production code, we recommend the optimized pandas data access methods, DataFrame.at(), DataFrame.iat(), DataFrame.loc() and DataFrame.iloc().

# %% [markdown]
# Selecting via [] (__getitem__), which slices the rows:

# %%
df[0:10]
# Out:
#   School     Sex  Age Address         Family_size Parent_cohabitation_status  \
# 0     GP  Female   18   Urban      Greater than 3                      Apart
# 1     GP  Female   17   Urban      Greater than 3            Living together
# 2     GP  Female   15   Urban  Less or equal to 3            Living together
# 3     GP  Female   15   Urban      Greater than 3            Living together
# 4     GP  Female   16   Urban      Greater than 3            Living together
# 5     GP    Male   16   Urban  Less or equal to 3            Living together
# 6     GP    Male   16   Urban  Less or equal to 3            Living together
# 7     GP  Female   17   Urban      Greater than 3                      Apart
# 8     GP    Male   15   Urban  Less or equal to 3                      Apart
# 9     GP    Male   15   Urban      Greater than 3            Living together
#
#    Mother_education  Father_education Mother_job Father_job  ... Famrel  \
# ...

# %% [markdown]
# # **Selection by label**
# See more in Selection by Label using DataFrame.loc() or DataFrame.at().

# %%
df.loc[0]
# Out:
# School                                    GP
# Sex                                   Female
# Age                                       18
# Address                                Urban
# Family_size                   Greater than 3
# Parent_cohabitation_status             Apart
# Mother_education                           4
# Father_education                           4
# Mother_job                           at_home
# Father_job                           teacher
# Reason                                course
# Guardian                              mother
# Trave_ltime                                2
# Study_time                                 2
# Failures                                   0
# Schoolsup                                yes
# Family_educational                        no
# Paid                                      no
# activities                                no
# Nursery                                  yes
# Higher                                   yes
# ...

# %% [markdown]
# # **Selecting on a multi-axis by label:**

# %%
df.loc[:, ["Higher", "G1"]]
# Out:
#     Higher  G1
# 0      yes   5
# 1      yes   5
# 2      yes   7
# 3      yes  15
# 4      yes   6
# ..     ...  ..
# 390    yes   9
# 391    yes  14
# 392    yes  10
# 393    yes  11
# 394    yes   8
#
# [395 rows x 2 columns]

# %% [markdown]
# # **Selection by position**

# %%
df.iloc[3]
# Out:
# School                                     GP
# Sex                                    Female
# Age                                        15
# Address                                 Urban
# Family_size                    Greater than 3
# Parent_cohabitation_status    Living together
# Mother_education                            4
# Father_education                            2
# Mother_job                             health
# Father_job                           services
# Reason                                   home
# Guardian                               mother
# Trave_ltime                                 1
# Study_time                                  3
# Failures                                    0
# Schoolsup                                  no
# Family_educational                        yes
# Paid                                      yes
# activities                                yes
# Nursery                                   yes
# ...

# %% [markdown]
# # **I’m interested in rows 10 till 25 and columns 3 to 5**

# %%
df.iloc[9:25,2:5]
# Out:
#     Age Address         Family_size
# 9    15   Urban      Greater than 3
# 10   15   Urban      Greater than 3
# 11   15   Urban      Greater than 3
# 12   15   Urban  Less or equal to 3
# 13   15   Urban      Greater than 3
# 14   15   Urban      Greater than 3
# 15   16   Urban      Greater than 3
# 16   16   Urban      Greater than 3
# 17   16   Urban      Greater than 3
# 18   17   Urban      Greater than 3
# 19   16   Urban  Less or equal to 3
# 20   15   Urban      Greater than 3
# 21   15   Urban      Greater than 3
# 22   16   Urban  Less or equal to 3
# 23   16   Urban  Less or equal to 3
# 24   15   Rural      Greater than 3

# %% [markdown]
# # **Boolean indexing**

# %% [markdown]
# ## **How do I select specific rows and columns from a DataFrame?**.

# %%
School_name= df.loc[df['G3']>15, 'School']
School_name
# Out:
# 8      GP
# 14     GP
# 22     GP
# 31     GP
# 32     GP
# 36     GP
# 42     GP
# 47     GP
# 59     GP
# 69     GP
# 91     GP
# 101    GP
# 104    GP
# 107    GP
# 109    GP
# 110    GP
# 113    GP
# 115    GP
# 129    GP
# 167    GP
# 171    GP
# 182    GP
# 196    GP
# 198    GP
# 200    GP
# 222    GP
# 245    GP
# 260    GP
# 265    GP
# 286    GP
# 293    GP
# 299    GP
# 303    GP
# 306    GP
# 326    GP
# 338    GP
# 346    GP
# 359    MS
# 374    MS
# 391    MS
# Name: School, dtype: object

# %% [markdown]
# ## Students Detail whose Grade2 is between  than 10 and 20

# %%
Grade_10_20= df[df['G2'].isin([10,20])]
Grade_10_20.shape
# Out:
# (46, 33)

# %% [markdown]
# # **Value Count**

# %%
df['Age'].value_counts()
# Out:
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: Age, dtype: int64

# %% [markdown]
# REMEMBER
# Import the package, aka import pandas as pd
#
# A table of data is stored as a pandas DataFrame
#
# Each column in a DataFrame is a Series
# Getting data in to pandas from many different file formats or data sources is supported by read_* functions.
#
# Exporting data out of pandas is provided by different to_*methods.
#
# The head/tail/info methods and the dtypes attribute are convenient for a first check.
#
#
# You can do things by applying a method to a DataFrame or Series
# When selecting subsets of data, square brackets [] are used.
#
# Inside these brackets, you can use a single column/row label, a list of column/row labels, a slice of labels, a conditional expression or a colon.
#
# Select specific rows and/or columns using loc when using the row and column names.
#
# Select specific rows and/or columns using iloc when using the positions in the table.
#
# You can assign new values to a selection based on loc/iloc.
